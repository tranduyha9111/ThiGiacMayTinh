# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/trand/img/hun.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>

# %%
region = (100, 75, 175, 175)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x100>

# %%
paste_potition = (250,150)
img.paste(cropped_image, paste_potition)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>
