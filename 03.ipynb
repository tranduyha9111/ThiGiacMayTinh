# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/trand/img/01.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=190x170>

# %%
print(img.size)
# Out:
# (190, 170)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=50x45>
